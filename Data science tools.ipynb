# %% [markdown]
# ## My jupyter Notebook on github
#
# #### My name is Amit Saini.
#
# #### I am 100% human.

# %%
I am interesting in data science because I love to gain the output from the data.

# %%
def recursive(n):
    if n<0:
        return n
    if n==0 or n==1:
        return 1
    else:
        return n*recursive(n-1)
a=recursive(6)
print(a)
# Out:
# 720

# %% [markdown]
# <html>
# <body>
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>
#
# </body>
# </html>
#
# <a href="https://www.ibm.com/">www.ibm.com</a>
# <html>
#     <body>
#         <table>
#             <tr>
#                 <th>Markdown</th>
#                 <th>Less</th>
#                 <th>Pretty</th>
#                 </tr>
#             <tr>
#                 <td>still</td>
#                 <td>renders</td>
#                 <td>nicely</td>
#                 </tr>
#             <tr>
#                 <td>1</td>
#                 <td>2</td>
#                 <td>2</td>
#                 </tr>
#             </table>
#         </body>
#     </html>
